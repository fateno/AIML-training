# %% [markdown]
# # Data Handling Using Pandas

# %%
import pandas as pd

# %%
df=pd.read_excel("students2.xlsx")

# %%
print ('Students record as follows:')
# Out:
# Students record as follows:

# %%
df
# Out:
#     Name  Age  Marks
# 0   John   20     85
# 1  Alice   22     90
# 2    Bob   21     78
# 3   Sara   23     92
# 4  Faten   35     80

# %%
data=pd.read_csv("archive/final_data.csv")

# %%
data
# Out:
#          Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0      34.91    Male        65.27        1.62   188.58   157.65        69.05
# 1      23.37  Female        56.41        1.55   179.43   131.75        73.18
# 2      33.20  Female        58.98        1.67   175.04   123.95        54.96
# 3      38.69  Female        93.78        1.70   191.21   155.10        50.07
# 4      45.09    Male        52.42        1.88   193.58   152.88        70.84
# ...      ...     ...          ...         ...      ...      ...          ...
# 19995  46.77  Female        98.31        1.90   199.20   148.18        63.72
# 19996  40.38  Female        88.12        1.87   196.18   134.18        54.04
# 19997  50.31    Male        46.20        1.67   163.34   157.92        61.65
# 19998  52.36    Male        44.30        1.62   179.27   121.23        60.88
# 19999  29.56    Male        58.63        1.61   198.07   121.74        72.05
#
# ...

# %%
selected_data=data[['Age','Gender','Max_BPM','Avg_BPM']]

# %%
selected_data.describe()
# Out:
#                 Age       Max_BPM       Avg_BPM
# count  20000.000000  20000.000000  20000.000000
# mean      38.851453    179.889702    143.704306
# std       12.114580     11.510805     14.267688
# min       18.000000    159.310000    119.070000
# 25%       28.170000    170.057500    131.220000
# 50%       39.865000    180.140000    142.990000
# 75%       49.630000    189.425000    156.060000
# max       59.670000    199.640000    169.840000

# %%
selected_data
# Out:
#          Age  Gender  Max_BPM  Avg_BPM
# 0      34.91    Male   188.58   157.65
# 1      23.37  Female   179.43   131.75
# 2      33.20  Female   175.04   123.95
# 3      38.69  Female   191.21   155.10
# 4      45.09    Male   193.58   152.88
# ...      ...     ...      ...      ...
# 19995  46.77  Female   199.20   148.18
# 19996  40.38  Female   196.18   134.18
# 19997  50.31    Male   163.34   157.92
# 19998  52.36    Male   179.27   121.23
# 19999  29.56    Male   198.07   121.74
#
# [20000 rows x 4 columns]

# %%
select_data=data[['Age','Gender','Weight (kg)']]

# %%
final_data=select_data[select_data["Weight (kg)"]>80]
compile_data=final_data[['Age', 'Gender', 'Weight (kg)']]

# %%
compile_data
# Out:
#          Age  Gender  Weight (kg)
# 3      38.69  Female        93.78
# 5      53.19  Female       105.05
# 7      55.92  Female        84.07
# 8      24.11  Female        88.58
# 10     50.51    Male        86.37
# ...      ...     ...          ...
# 19982  53.10    Male       115.30
# 19985  43.01  Female        95.67
# 19993  28.52  Female        87.72
# 19995  46.77  Female        98.31
# 19996  40.38  Female        88.12
#
# [6586 rows x 3 columns]

# %%
final_data
# Out:
#          Age  Gender  Weight (kg)
# 0      34.91    Male        65.27
# 3      38.69  Female        93.78
# 5      53.19  Female       105.05
# 7      55.92  Female        84.07
# 8      24.11  Female        88.58
# ...      ...     ...          ...
# 19992  28.59  Female        68.43
# 19993  28.52  Female        87.72
# 19994  39.38    Male        64.13
# 19995  46.77  Female        98.31
# 19996  40.38  Female        88.12
#
# [14169 rows x 3 columns]

# %%
top_students=df[df["Marks"]>80]a

# %%
top_students
# Out:
#     Name  Age  Marks
# 0   John   20     85
# 1  Alice   22     90
# 3   Sara   23     92

# %%
rejected_students=df[df["Marks"]<=80]

# %%
rejected_students
# Out:
#     Name  Age  Marks
# 2    Bob   21     78
# 4  Faten   35     80

# %%
df
# Out:
#     Name  Age  Marks
# 0   John   20     85
# 1  Alice   22     90
# 2    Bob   21     78
# 3   Sara   23     92

# %%
top_students.to_excel("selected_students.xlsx", index=False)
print ("Filtered data saved to 'selected_students.xlsx'")
# Out:
# Filtered data saved to 'selected_students.xlsx'

# %%
df
# Out:
#     Name  Age  Marks
# 0   John   20     85
# 1  Alice   22     90
# 2    Bob   21     78
# 3   Sara   23     92

# %%
top_students.to_excel("rejected_students.xlsx", index=False)
print ("Filtered data saved to 'rejected_students.xlsx'")
# Out:
# Filtered data saved to 'rejected_students.xlsx'

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jaderz/hospital-beds-management")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|███████████████████████████████████████| 46.5k/46.5k [00:00<00:00, 335kB/s]
# Extracting files...
# Path to dataset files: /Users/fateno/.cache/kagglehub/datasets/jaderz/hospital-beds-management/versions/1

# %% [markdown]
# # Use patient file and display all record

# %% [markdown]
# Show number of rows and columns in your dataset

# %%
patients_list=pd.read_csv("archive_hospital/patients.csv")

# %%
patients_list
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1    PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2    PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3    PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4    PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# ..            ...                ...  ...          ...            ...
# 995  PAT-a01bf534         Amber Vang   26   2025-12-02     2025-12-04
# 996  PAT-87fa07bd       Martha Smith   89   2025-11-18     2025-11-30
# 997  PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
# 999  PAT-e2ef9c5f    Lorraine Turner   64   2025-05-04     2025-05-08
#
#               service  satisfaction
# 0             surgery            61
# 1             surgery            83
# ...

# %%
patients_list.describe()
# Out:
#                age  satisfaction
# count  1000.000000   1000.000000
# mean     45.337000     79.597000
# std      25.999912     11.550325
# min       0.000000     60.000000
# 25%      23.000000     70.000000
# 50%      46.000000     80.000000
# 75%      68.000000     89.250000
# max      89.000000     99.000000

# %%
rows,cols=patients_list.shape
print ('Rows:', rows)
print ('Columns:', cols)
# Out:
# Rows: 1000
# Columns: 7

# %%
patients_list.head(0)
# Out:
# Empty DataFrame
# Columns: [patient_id, name, age, arrival_date, departure_date, service, satisfaction]
# Index: []

# %%
icu_patients=patients_list[["service"]=='ICU']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 icu_patients=patients_list[["service"]==ICU]
#
# NameError: name 'ICU' is not defined
